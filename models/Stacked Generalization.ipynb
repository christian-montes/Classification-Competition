# %% [markdown]
# ## Stacked Generalization
#
# In this notebook I will use the Stacked Generalization method to try to increase the accuracy of the models that I have previously used.

# %%
# loading a few of the classes that I will need
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import KNNImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler, OrdinalEncoder

# %% [markdown]
# Now I will read in the training data and split it into three groups that will be used to train the models and then train the stacking classifier.

# %%
train_path=os.path.join('..','data','processed','train.csv')

# to have all the columns displayed
pd.set_option('display.max_columns', 80)

train_data=pd.read_csv(train_path)
train_data
# Out:
#         id  hi_int_prncp_pd  acc_now_delinq  acc_open_past_24mths addr_state  \
# 0     3819                0               0                     2         CT
# 1     3820                0               0                     3         CA
# 2     3821                0               0                     3         NY
# 3     3822                0               0                     1         NJ
# 4     3823                0               0                     2         MO
# ...    ...              ...             ...                   ...        ...
# 5773  9592                1               0                    10         VA
# 5774  9593                1               0                     2         CA
# 5775  9594                1               0                     3         MD
# 5776  9595                1               0                     5         FL
# 5777  9596                1               0                     8         TX
#
#       annual_inc application_type  avg_cur_bal  bc_util  delinq_2yrs  \
# 0        21120.0       Individual         3662     86.1            0
# 1        32400.0       Individual         2973     30.2            0
# 2        30251.0       Individual         1983     46.2            0
# 3        66976.0       Individual         1638     77.4            0
# 4       125000.0       Individual          577      0.0            0
# ...          ...              ...          ...      ...          ...
# 5773     72000.0       Individual        12881     89.7            0
# 5774    125000.0       Individual       104603     90.2            0
# 5775     95000.0       Individual        22815     96.5            0
# 5776     42000.0       Individual         2586     96.3            0
# 5777    109142.0       Individual        17454     40.9            1
#
#       delinq_amnt    dti  earliest_cr_line  emp_length  \
# 0               0  33.69              2010         1.0
# 1               0  15.78              1975         3.0
# 2               0  20.04              2010         2.0
# 3               0   8.58              2012         1.0
# 4               0   2.34              1982        10.0
# ...           ...    ...               ...         ...
# 5773            0  24.50              2008         3.0
# 5774            0   6.39              2005        10.0
# 5775            0  28.45              1993        10.0
# 5776            0  18.20              1999        10.0
# 5777            0  15.39              2005         2.0
#
#                                emp_title grade home_ownership  \
# 0                         Security Guard     C           RENT
# 1                         Security Guard     C            OWN
# 2                         Security Guard     B           RENT
# 3                         Security Guard     C            OWN
# 4                          Administrator     A       MORTGAGE
# ...                                  ...   ...            ...
# 5773  Transportation Security Specialist     D           RENT
# 5774                 Stationary Engineer     C            OWN
# 5775              Infrastructure Analyst     B       MORTGAGE
# 5776                  Quality Supervisor     C           RENT
# 5777                   Claims Supervisor     C       MORTGAGE
#
#      initial_list_status  int_rate  last_credit_pull_d  loan_amnt  mort_acc  \
# 0                      w     12.62                2019       7000         0
# 1                      w     11.99                2016      16200         2
# 2                      w     11.49                2018       9600         0
# 3                      w     12.62                2019      12000         0
# 4                      w      6.49                2019      24000         4
# ...                  ...       ...                 ...        ...       ...
# 5773                   w     18.25                2019      20000         0
# 5774                   w     16.01                2019      15000         2
# 5775                   w     11.53                2019      32000         2
# 5776                   w     13.67                2019      12000         0
# 5777                   w     15.99                2019      32000         4
#
#       num_sats  num_tl_120dpd_2m  num_tl_90g_dpd_24m  num_tl_30dpd  \
# 0           18                 0                   0             0
# 1            8                 0                   0             0
# 2           10                 0                   0             0
# 3            6                 0                   0             0
# 4           13                 0                   0             0
# ...        ...               ...                 ...           ...
# 5773        13                 0                   0             0
# 5774         4                 0                   0             0
# 5775        18                 0                   0             0
# 5776         8                 0                   0             0
# 5777        22                 0                   0             0
#
#       out_prncp_inv  pub_rec  pub_rec_bankruptcies             purpose  \
# 0           3828.54        0                     0  debt_consolidation
# 1              0.00        3                     2  debt_consolidation
# 2              0.00        0                     0  debt_consolidation
# 3           9665.27        0                     0  debt_consolidation
# 4          11358.24        0                     0  debt_consolidation
# ...             ...      ...                   ...                 ...
# 5773        6070.29        0                     0  debt_consolidation
# 5774       13250.14        0                     0               other
# 5775        9188.48        0                     0  debt_consolidation
# 5776        5791.18        0                     0         credit_card
# 5777       23544.05        0                     0  debt_consolidation
#
#      sub_grade  term  tot_coll_amt  tot_cur_bal  total_rec_late_fee  \
# 0           C1    36             0        65921                0.00
# 1           C1    36             0        17840                0.00
# 2           B5    36             0        19829                0.00
# 3           C1    60             0         9830                0.00
# 4           A2    60             0         6924                0.00
# ...        ...   ...           ...          ...                 ...
# 5773        D3    36             0       167450              253.96
# 5774        C5    60             0       523017                0.00
# 5775        B5    60             0       410676                0.00
# 5776        C3    60             0        20684                0.00
# 5777        C5    60             0       331634                0.00
#
#       verification_status
# 0                       1
# 1                       0
# 2                       1
# 3                       1
# 4                       1
# ...                   ...
# 5773                    1
# 5774                    0
# 5775                    1
# 5776                    1
# 5777                    1
#
# [5778 rows x 36 columns]

# %%
# seperating the target variable
y=train_data['hi_int_prncp_pd'].copy()

train_data=train_data.drop(columns=['hi_int_prncp_pd', 'addr_state', 'purpose', 'emp_title', 'id'], axis=1)

train_data['verification_status']=train_data['verification_status'].astype('object')

# %%
# creating a training, validation, and a test set
# splitting both using the default 25% split
x_train, x_test, y_train, y_test=train_test_split(train_data, y, stratify=y, random_state=402)
x_train.head()
# Out:
#       acc_now_delinq  acc_open_past_24mths  annual_inc application_type  \
# 3571               0                     8    250000.0       Individual
# 4881               0                     6     49000.0       Individual
# 181                0                     1     51460.0       Individual
# 4587               0                     2    110000.0       Individual
# 2369               0                     1     72400.0       Individual
#
#       avg_cur_bal  bc_util  delinq_2yrs  delinq_amnt    dti  earliest_cr_line  \
# 3571        51612     39.5            2            0   9.78              2003
# 4881         9842     38.3            1            0  29.24              2003
# 181          3460     61.1            0            0  18.54              1999
# 4587         8733     22.0            0            0  17.99              2002
# 2369        32761     81.3            0            0  33.27              1995
#
#       emp_length grade home_ownership initial_list_status  int_rate  \
# 3571        10.0     A       MORTGAGE                   w      6.49
# 4881         1.0     E       MORTGAGE                   w     25.81
# 181         10.0     B           RENT                   w     10.41
# 4587         2.0     A       MORTGAGE                   w      5.32
# 2369         1.0     D       MORTGAGE                   w     15.61
#
#       last_credit_pull_d  loan_amnt  mort_acc  num_sats  num_tl_120dpd_2m  \
# 3571                2018      21000         8        13                 0
# 4881                2019      16000         1        23                 0
# 181                 2019      15000         1         6                 0
# 4587                2018      20000         3        19                 0
# 2369                2016      18925         2        16                 0
#
#       num_tl_90g_dpd_24m  num_tl_30dpd  out_prncp_inv  pub_rec  \
# 3571                   0             0           0.00        0
# 4881                   1             0       15305.16        0
# 181                    0             0       10508.39        0
# 4587                   0             0           0.00        0
# 2369                   0             0           0.00        0
#
#       pub_rec_bankruptcies sub_grade  term  tot_coll_amt  tot_cur_bal  \
# 3571                     0        A2    60             0       670956
# 4881                     0        E4    60             0       226374
# 181                      0        B3    36             0        17302
# 4587                     0        A1    36             0       165926
# 2369                     0        D1    36             0       393132
#
#       total_rec_late_fee verification_status
# 3571                 0.0                   1
# 4881                 0.0                   1
# 181                  0.0                   1
# 4587                 0.0                   0
# 2369                 0.0                   0

# %% [markdown]
# ### Making the Base Learner's Pipelines:

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4333 entries, 3571 to 3206
# Data columns (total 31 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   acc_now_delinq        4333 non-null   int64
#  1   acc_open_past_24mths  4333 non-null   int64
#  2   annual_inc            4333 non-null   float64
#  3   application_type      4333 non-null   object
#  4   avg_cur_bal           4333 non-null   int64
#  5   bc_util               4333 non-null   float64
#  6   delinq_2yrs           4333 non-null   int64
#  7   delinq_amnt           4333 non-null   int64
#  8   dti                   4333 non-null   float64
#  9   earliest_cr_line      4333 non-null   int64
#  10  emp_length            4332 non-null   float64
#  11  grade                 4333 non-null   object
#  12  home_ownership        4333 non-null   object
#  13  initial_list_status   4333 non-null   object
#  14  int_rate              4333 non-null   float64
#  15  last_credit_pull_d    4333 non-null   int64
#  16  loan_amnt             4333 non-null   int64
#  17  mort_acc              4333 non-null   int64
#  18  num_sats              4333 non-null   int64
#  19  num_tl_120dpd_2m      4333 non-null   int64
#  20  num_tl_90g_dpd_24m    4333 non-null   int64
#  21  num_tl_30dpd          4333 non-null   int64
#  22  out_prncp_inv         4333 non-null   float64
#  23  pub_rec               4333 non-null   int64
#  24  pub_rec_bankruptcies  4333 non-null   int64
#  25  sub_grade             4333 non-null   object
#  26  term                  4333 non-null   int64
#  27  tot_coll_amt          4333 non-null   int64
#  28  tot_cur_bal           4333 non-null   int64
#  29  total_rec_late_fee    4333 non-null   float64
#  30  verification_status   4333 non-null   object
# dtypes: float64(7), int64(18), object(6)
# memory usage: 1.1+ MB

# %% [markdown]
# There are 7 float, 19 int, and 6 object.
#
# All the categorical will be one-hot encoded for the SVM. The other numeric attributes will be scaled using the StandardScaler.

# %%
cat_attribs=list(x_train.select_dtypes(include=['object']))
cat_attribs
# Out:
# ['application_type',
#  'grade',
#  'home_ownership',
#  'initial_list_status',
#  'sub_grade',
#  'verification_status']

# %%
num_attribs=list(x_train.select_dtypes(include=['int64', 'float64']))
num_attribs
# Out:
# ['acc_now_delinq',
#  'acc_open_past_24mths',
#  'annual_inc',
#  'avg_cur_bal',
#  'bc_util',
#  'delinq_2yrs',
#  'delinq_amnt',
#  'dti',
#  'earliest_cr_line',
#  'emp_length',
#  'int_rate',
#  'last_credit_pull_d',
#  'loan_amnt',
#  'mort_acc',
#  'num_sats',
#  'num_tl_120dpd_2m',
#  'num_tl_90g_dpd_24m',
#  'num_tl_30dpd',
#  'out_prncp_inv',
#  'pub_rec',
#  'pub_rec_bankruptcies',
#  'term',
#  'tot_coll_amt',
#  'tot_cur_bal',
#  'total_rec_late_fee']

# %% [markdown]
# Creating the SVM Pipeline

# %%
# creating the num pipeline in order to handle the missing values that may arise
from sklearn.svm import SVC

svm_num_pipeline=Pipeline([
    ('imputer', KNNImputer(n_neighbors=5)),
    ('num', StandardScaler())
])

svm_transformer=ColumnTransformer([
    ('num', num_pipeline, num_attribs),
    ('cat', OneHotEncoder(handle_unknown='ignore'), cat_attribs)
])

# %% [markdown]
# Creating the pipeline for the Extra Trees Classifier.

# %%
from sklearn.ensemble import ExtraTreesClassifier

ex_trees_num_pipeline=Pipeline([
    ('imputer', KNNImputer(n_neighbors=5))
])

ex_trees_transformer=ColumnTransformer([
    ('num', num_pipeline, num_attribs),
    ('cat', OneHotEncoder(handle_unknown='ignore'), cat_attribs)
])

# %% [markdown]
# Creating the KNN Classifier pipeline

# %%
from sklearn.neighbors import KNeighborsClassifier

knn_num_pipeline=Pipeline([
    ('imputer', KNNImputer(n_neighbors=5)),
    ('num', StandardScaler())
])

knn_transformer=ColumnTransformer([
    ('num', num_pipeline, num_attribs),
    ('cat', OneHotEncoder(handle_unknown='ignore'), cat_attribs)
])

# %% [markdown]
# Creating the XGBoost pipeline

# %%
from xgboost.sklearn import XGBClassifier

xgboost_pipeline=ColumnTransformer([
    ('num', KNNImputer(n_neighbors=5), num_attribs),
    ('cat', OneHotEncoder(handle_unknown='ignore'), cat_attribs)
])

# %% [markdown]
# Creating the LightGBM pipeline:

# %%
from lightgbm.sklearn import LGBMClassifier

lgbm_pipeline=ColumnTransformer([
    ('num', KNNImputer(n_neighbors=5), num_attribs),
    ('cat', OneHotEncoder(handle_unknown='ignore'), cat_attribs)
])

# %% [markdown]
# Here I will create the Stacking Classifier by first creating a list that contains the 5 different classifiers.

# %%
estimators=[
    ('svm', make_pipeline(svm_transformer,
                          SVC(kernel='rbf', random_state=402))),
    
    ('extra_trees', make_pipeline(ex_trees_transformer,
                                  ExtraTreesClassifier(n_estimators=100, random_state=402))),
    
    ('knn', make_pipeline(knn_transformer,
                          KNeighborsClassifier(n_neighbors=5, weights='distance'))),
    
    ('xgb', make_pipeline(xgboost_pipeline,
                          XGBClassifier(objective='binary:logistic', n_estimators=100, random_state=402))),
    
    ('lgbm', make_pipeline(lgbm_pipeline,
                           LGBMClassifier(objective='binary', n_estimators=100, random_state=402)))
]

# %% [markdown]
# Now I will fit the estimators using the fit method of the Stacking Classifier class.
#
# I will use Logistic Regression as the final estimator to make the final predictions.

# %%
from sklearn.ensemble import StackingClassifier
from sklearn.linear_model import LogisticRegression

stack_clf=StackingClassifier(estimators=estimators,
                            final_estimator=LogisticRegression())

# %% [markdown]
# Finally here we will get the accuracy that the model achieves using the score method of the Classifier

# %%
# %time stack_clf.fit(x_train, y_train).score(x_test, y_test)
# Out:
# CPU times: user 35.2 s, sys: 385 ms, total: 35.6 s
# Wall time: 15.4 s
# 0.9107266435986159

# %% [markdown]
# We got an accuracy of 91.1%.
#
# I will now load the test data into memory

# %%
test_path=os.path.join('..', 'data', 'processed', 'test.csv')

test_data=pd.read_csv(test_path)

id_col=test_data['id'].copy()

test_data.head()
# Out:
#    id  acc_now_delinq  acc_open_past_24mths addr_state  annual_inc  \
# 0   1               0                    10         NY     45000.0
# 1   2               0                     1         NY     40000.0
# 2   3               0                     1         FL    113000.0
# 3   4               0                     6         CA    105000.0
# 4   5               0                     9         CA     80000.0
#
#   application_type  avg_cur_bal  bc_util  delinq_2yrs  delinq_amnt    dti  \
# 0       Individual         3125     40.6            0            0  27.60
# 1       Individual         1534     26.6            0            0  17.54
# 2       Individual        49748     82.6            0            0  19.67
# 3       Individual        42642     81.8            0            0  30.47
# 4       Individual         4766     52.2            0            0  22.94
#
#    earliest_cr_line  emp_length       emp_title grade home_ownership  \
# 0              1987        10.0  Security Guard     D           RENT
# 1              2010         3.0  Security Guard     B            OWN
# 2              1999         8.0   Administrator     A       MORTGAGE
# 3              1988        10.0   Administrator     B       MORTGAGE
# 4              1990        10.0   Administrator     A           RENT
#
#   initial_list_status  int_rate  last_credit_pull_d  loan_amnt  mort_acc  \
# 0                   w     17.57                2018      10000         0
# 1                   w      8.24                2017      14400         0
# 2                   w      7.49                2019      30000         4
# 3                   w      8.18                2019      10000         2
# 4                   w      5.32                2019       6000         0
#
#    num_sats  num_tl_120dpd_2m  num_tl_90g_dpd_24m  num_tl_30dpd  \
# 0        21                 0                   0             0
# 1        10                 0                   0             0
# 2         9                 0                   0             0
# 3        12                 0                   0             0
# 4        21                 0                   0             0
#
#    out_prncp_inv  pub_rec  pub_rec_bankruptcies             purpose sub_grade  \
# 0           0.00        0                     0             medical        D4
# 1           0.00        0                     0         credit_card        B1
# 2        8141.22        0                     0  debt_consolidation        A4
# 3           0.00        0                     0         credit_card        B1
# 4           0.00        0                     0    home_improvement        A1
#
#    term  tot_coll_amt  tot_cur_bal  total_rec_late_fee  verification_status
# 0    60           379        65615                 0.0                    1
# 1    36             0        13806                 0.0                    0
# 2    36             0       447731                 0.0                    1
# 3    36             0       469067                 0.0                    0
# 4    36             0       100087                 0.0                    0

# %%
test_data.drop(columns=['addr_state', 'purpose', 'emp_title', 'id'], axis=1, inplace=True)

# %%
# looking at the data one last time before feeding it into the Stacking Classifier
test_data.head()
# Out:
#    acc_now_delinq  acc_open_past_24mths  annual_inc application_type  \
# 0               0                    10     45000.0       Individual
# 1               0                     1     40000.0       Individual
# 2               0                     1    113000.0       Individual
# 3               0                     6    105000.0       Individual
# 4               0                     9     80000.0       Individual
#
#    avg_cur_bal  bc_util  delinq_2yrs  delinq_amnt    dti  earliest_cr_line  \
# 0         3125     40.6            0            0  27.60              1987
# 1         1534     26.6            0            0  17.54              2010
# 2        49748     82.6            0            0  19.67              1999
# 3        42642     81.8            0            0  30.47              1988
# 4         4766     52.2            0            0  22.94              1990
#
#    emp_length grade home_ownership initial_list_status  int_rate  \
# 0        10.0     D           RENT                   w     17.57
# 1         3.0     B            OWN                   w      8.24
# 2         8.0     A       MORTGAGE                   w      7.49
# 3        10.0     B       MORTGAGE                   w      8.18
# 4        10.0     A           RENT                   w      5.32
#
#    last_credit_pull_d  loan_amnt  mort_acc  num_sats  num_tl_120dpd_2m  \
# 0                2018      10000         0        21                 0
# 1                2017      14400         0        10                 0
# 2                2019      30000         4         9                 0
# 3                2019      10000         2        12                 0
# 4                2019       6000         0        21                 0
#
#    num_tl_90g_dpd_24m  num_tl_30dpd  out_prncp_inv  pub_rec  \
# 0                   0             0           0.00        0
# 1                   0             0           0.00        0
# 2                   0             0        8141.22        0
# 3                   0             0           0.00        0
# 4                   0             0           0.00        0
#
#    pub_rec_bankruptcies sub_grade  term  tot_coll_amt  tot_cur_bal  \
# 0                     0        D4    60           379        65615
# 1                     0        B1    36             0        13806
# 2                     0        A4    36             0       447731
# 3                     0        B1    36             0       469067
# 4                     0        A1    36             0       100087
#
#    total_rec_late_fee  verification_status
# 0                 0.0                    1
# 1                 0.0                    0
# 2                 0.0                    1
# 3                 0.0                    0
# 4                 0.0                    0

# %%
stack_predictions=pd.DataFrame(stack_clf.predict(test_data)).rename(columns={0:'Category'})
stack_predictions.head()
# Out:
#    Category
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
stack_submission=pd.concat([id_col, stack_predictions], axis=1)
stack_submission.rename(columns={'id':'Id'}, inplace=True)
stack_submission['Category']=stack_submission['Category'].apply(str)
stack_submission.head()
# Out:
#    Id Category
# 0   1        0
# 1   2        0
# 2   3        0
# 3   4        0
# 4   5        0

# %%
stack_submission.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Id        3818 non-null   int64
#  1   Category  3818 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 59.8+ KB

# %%
# path to write file
prediction_path=os.path.join('..', 'data', 'predictions', 'stacking_preds.csv')

stack_submission.to_csv(prediction_path, index=False)

# %% [markdown]
# We will see how the predictions do on the test set from Kaggle.
#
# This model scored 92.563% on the test data. This is higher than what we got from the validation data.
